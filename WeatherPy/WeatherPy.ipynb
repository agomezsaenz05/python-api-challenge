# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | caravelas
# Processing Record 6 of Set 1 | constitucion
# Processing Record 7 of Set 1 | seoul
# Processing Record 8 of Set 1 | necochea
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | jasper
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | lasa
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | flinders
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | minudasht
# Processing Record 22 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | luganville
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | khatanga
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | naantali
# Processing Record 30 of Set 1 | nome
# Processing Record 31 of Set 1 | tanete
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | havre-saint-pierre
# Processing Record 34 of Set 1 | north bend
# Processing Record 35 of Set 1 | ixtapa
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | sioux lookout
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | pacific grove
# Processing Record 42 of Set 1 | keetmanshoop
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | vieux-habitants
# Processing Record 45 of Set 1 | yining
# Processing Record 46 of Set 1 | santa ana
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | lethem
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 0 of Set 2 | palmer
# Processing Record 1 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | kalevala
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | houma
# Processing Record 8 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 2 | kuminskiy
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | kualakapuas
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | zhigansk
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | nikolskoye
# Processing Record 18 of Set 2 | mossendjo
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | linguere
# Processing Record 21 of Set 2 | tucuman
# Processing Record 22 of Set 2 | gao
# Processing Record 23 of Set 2 | roald
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | ancud
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | san luis
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | katra
# Processing Record 31 of Set 2 | orlik
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | belaya gora
# Processing Record 34 of Set 2 | gorontalo
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | catio
# Processing Record 37 of Set 2 | great yarmouth
# Processing Record 38 of Set 2 | sao jose da coroa grande
# Processing Record 39 of Set 2 | am timan
# Processing Record 40 of Set 2 | ploemeur
# Processing Record 41 of Set 2 | hovd
# Processing Record 42 of Set 2 | umarkhed
# Processing Record 43 of Set 2 | saint-joseph
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | manono
# Processing Record 48 of Set 2 | nizhniy kuranakh
# Processing Record 49 of Set 2 | porbandar
# Processing Record 0 of Set 3 | bandarbeyla
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | kloulklubed
# Processing Record 3 of Set 3 | mogadishu
# Processing Record 4 of Set 3 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 5 of Set 3 | lata
# Processing Record 6 of Set 3 | flin flon
# Processing Record 7 of Set 3 | saldanha
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | lompoc
# Processing Record 11 of Set 3 | fort nelson
# Processing Record 12 of Set 3 | mwinilunga
# Processing Record 13 of Set 3 | tarija
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | vizinga
# Processing Record 16 of Set 3 | nogliki
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | manta
# Processing Record 19 of Set 3 | suao
# City not found. Skipping...
# Processing Record 20 of Set 3 | kununurra
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | launceston
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | sakakah
# Processing Record 29 of Set 3 | yemelyanovo
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | laguna
# Processing Record 35 of Set 3 | ngorongoro
# Processing Record 36 of Set 3 | quatre cocos
# Processing Record 37 of Set 3 | boa viagem
# Processing Record 38 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 3 | sao fidelis
# Processing Record 40 of Set 3 | vanderhoof
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | mulege
# Processing Record 43 of Set 3 | saint-georges
# Processing Record 44 of Set 3 | rudnogorsk
# Processing Record 45 of Set 3 | fairlie
# Processing Record 46 of Set 3 | harper
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | charters towers
# Processing Record 0 of Set 4 | esperance
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | haicheng
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | thio
# Processing Record 6 of Set 4 | paramonga
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | sao filipe
# Processing Record 10 of Set 4 | arraial do cabo
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 13 of Set 4 | tabuk
# Processing Record 14 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 4 | atbasar
# Processing Record 16 of Set 4 | castro
# Processing Record 17 of Set 4 | aksarka
# Processing Record 18 of Set 4 | burnie
# Processing Record 19 of Set 4 | bella vista
# Processing Record 20 of Set 4 | vredendal
# Processing Record 21 of Set 4 | bayir
# Processing Record 22 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 4 | shingu
# Processing Record 24 of Set 4 | acarau
# Processing Record 25 of Set 4 | haines junction
# Processing Record 26 of Set 4 | mecca
# Processing Record 27 of Set 4 | isangel
# Processing Record 28 of Set 4 | naron
# Processing Record 29 of Set 4 | iranshahr
# Processing Record 30 of Set 4 | ferrol
# Processing Record 31 of Set 4 | kozan
# Processing Record 32 of Set 4 | miles city
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | monroe
# Processing Record 35 of Set 4 | bignona
# Processing Record 36 of Set 4 | brazzaville
# Processing Record 37 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | venafro
# Processing Record 40 of Set 4 | kapaa
# Processing Record 41 of Set 4 | pemangkat
# Processing Record 42 of Set 4 | kovdor
# Processing Record 43 of Set 4 | rawson
# Processing Record 44 of Set 4 | cuamba
# Processing Record 45 of Set 4 | phangnga
# Processing Record 46 of Set 4 | vega de alatorre
# Processing Record 47 of Set 4 | saint george
# Processing Record 48 of Set 4 | mazulskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | piacabucu
# Processing Record 0 of Set 5 | sorland
# Processing Record 1 of Set 5 | novovarshavka
# Processing Record 2 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 5 | port lincoln
# Processing Record 4 of Set 5 | honningsvag
# Processing Record 5 of Set 5 | itoman
# Processing Record 6 of Set 5 | peruibe
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | la joya
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | shenjiamen
# Processing Record 13 of Set 5 | yomou
# Processing Record 14 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 5 | airai
# Processing Record 16 of Set 5 | mareeba
# Processing Record 17 of Set 5 | makakilo city
# Processing Record 18 of Set 5 | mandalgovi
# Processing Record 19 of Set 5 | matane
# Processing Record 20 of Set 5 | krasnaya gorka
# Processing Record 21 of Set 5 | nybro
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | salina
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | tesanjka
# Processing Record 27 of Set 5 | tsogni
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 5 | qaqortoq
# Processing Record 31 of Set 5 | okhotsk
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | urucara
# Processing Record 34 of Set 5 | tonantins
# Processing Record 35 of Set 5 | yerbogachen
# Processing Record 36 of Set 5 | mandurah
# Processing Record 37 of Set 5 | comodoro rivadavia
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | ola
# Processing Record 41 of Set 5 | kuli
# Processing Record 42 of Set 5 | grand gaube
# Processing Record 43 of Set 5 | rocha
# Processing Record 44 of Set 5 | caracuaro
# Processing Record 45 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 5 | laiagam
# City not found. Skipping...
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | svetlaya
# Processing Record 49 of Set 5 | alice springs
# Processing Record 0 of Set 6 | leticia
# Processing Record 1 of Set 6 | verdun
# Processing Record 2 of Set 6 | vrangel
# Processing Record 3 of Set 6 | gat
# Processing Record 4 of Set 6 | the valley
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | maymyo
# Processing Record 7 of Set 6 | fernley
# Processing Record 8 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | oia
# Processing Record 11 of Set 6 | villamartin
# Processing Record 12 of Set 6 | tasiilaq
# Processing Record 13 of Set 6 | kiunga
# Processing Record 14 of Set 6 | talah
# City not found. Skipping...
# Processing Record 15 of Set 6 | broken hill
# Processing Record 16 of Set 6 | bonfim
# Processing Record 17 of Set 6 | bjerkvik
# Processing Record 18 of Set 6 | niksar
# Processing Record 19 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 6 | valdez
# Processing Record 21 of Set 6 | staicele
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | boende
# Processing Record 25 of Set 6 | evensk
# Processing Record 26 of Set 6 | san patricio
# Processing Record 27 of Set 6 | srednekolymsk
# Processing Record 28 of Set 6 | srivardhan
# Processing Record 29 of Set 6 | iglas
# Processing Record 30 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 6 | mbandaka
# Processing Record 32 of Set 6 | miramar
# Processing Record 33 of Set 6 | yefira
# City not found. Skipping...
# Processing Record 34 of Set 6 | isabela
# Processing Record 35 of Set 6 | pingyi
# Processing Record 36 of Set 6 | atlantic city
# Processing Record 37 of Set 6 | maragogi
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | ardesen
# Processing Record 40 of Set 6 | sibolga
# Processing Record 41 of Set 6 | egvekinot
# Processing Record 42 of Set 6 | naduvattam
# Processing Record 43 of Set 6 | namatanai
# Processing Record 44 of Set 6 | pokhara
# Processing Record 45 of Set 6 | trelew
# Processing Record 46 of Set 6 | shimoda
# Processing Record 47 of Set 6 | minot
# Processing Record 48 of Set 6 | newport
# Processing Record 49 of Set 6 | hami
# Processing Record 0 of Set 7 | saint-pierre
# Processing Record 1 of Set 7 | grindavik
# Processing Record 2 of Set 7 | hambantota
# Processing Record 3 of Set 7 | gayeri
# Processing Record 4 of Set 7 | champerico
# Processing Record 5 of Set 7 | pocosol
# Processing Record 6 of Set 7 | high level
# Processing Record 7 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 8 of Set 7 | yangjiang
# Processing Record 9 of Set 7 | torbay
# Processing Record 10 of Set 7 | minas
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | zvishavane
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | veraval
# Processing Record 16 of Set 7 | te anau
# Processing Record 17 of Set 7 | havelock
# Processing Record 18 of Set 7 | santo anastacio
# Processing Record 19 of Set 7 | aksay
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 7 | elk city
# Processing Record 23 of Set 7 | parichha
# Processing Record 24 of Set 7 | beloha
# Processing Record 25 of Set 7 | karratha
# Processing Record 26 of Set 7 | macusani
# Processing Record 27 of Set 7 | sebinkarahisar
# Processing Record 28 of Set 7 | chokurdakh
# Processing Record 29 of Set 7 | chuy
# Processing Record 30 of Set 7 | nicoya
# Processing Record 31 of Set 7 | eureka
# Processing Record 32 of Set 7 | pudozh
# Processing Record 33 of Set 7 | kavaratti
# Processing Record 34 of Set 7 | samarai
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | faanui
# Processing Record 37 of Set 7 | teguldet
# Processing Record 38 of Set 7 | pangnirtung
# Processing Record 39 of Set 7 | atar
# Processing Record 40 of Set 7 | atikokan
# Processing Record 41 of Set 7 | bengkulu
# Processing Record 42 of Set 7 | port moresby
# Processing Record 43 of Set 7 | sfantu gheorghe
# Processing Record 44 of Set 7 | biak
# Processing Record 45 of Set 7 | prince rupert
# Processing Record 46 of Set 7 | yeppoon
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | santa adelia
# Processing Record 49 of Set 7 | demba
# Processing Record 0 of Set 8 | ballina
# Processing Record 1 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 8 | huarmey
# Processing Record 3 of Set 8 | mayo
# Processing Record 4 of Set 8 | taoudenni
# Processing Record 5 of Set 8 | clinton
# Processing Record 6 of Set 8 | san jose
# Processing Record 7 of Set 8 | turukhansk
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | bonavista
# Processing Record 12 of Set 8 | plymouth
# Processing Record 13 of Set 8 | ilula
# Processing Record 14 of Set 8 | college
# Processing Record 15 of Set 8 | victoria
# Processing Record 16 of Set 8 | touros
# Processing Record 17 of Set 8 | lorengau
# Processing Record 18 of Set 8 | saint-esteve
# Processing Record 19 of Set 8 | mountmellick
# Processing Record 20 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 8 | pareora
# Processing Record 22 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 8 | aygedzor
# Processing Record 24 of Set 8 | vierzon
# Processing Record 25 of Set 8 | addi ugri
# City not found. Skipping...
# Processing Record 26 of Set 8 | thonon-les-bains
# Processing Record 27 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 8 | woodend
# Processing Record 29 of Set 8 | vostok
# Processing Record 30 of Set 8 | serowe
# Processing Record 31 of Set 8 | jiuquan
# Processing Record 32 of Set 8 | aklavik
# Processing Record 33 of Set 8 | nova petropolis
# Processing Record 34 of Set 8 | kailua
# Processing Record 35 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 36 of Set 8 | bathsheba
# Processing Record 37 of Set 8 | halifax
# Processing Record 38 of Set 8 | korla
# Processing Record 39 of Set 8 | cacahuatepec
# Processing Record 40 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | salto de agua
# Processing Record 43 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 8 | birao
# Processing Record 45 of Set 8 | orocue
# Processing Record 46 of Set 8 | padang
# Processing Record 47 of Set 8 | hrob
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | baherden
# Processing Record 0 of Set 9 | viedma
# Processing Record 1 of Set 9 | baykit
# Processing Record 2 of Set 9 | panzhihua
# Processing Record 3 of Set 9 | tambacounda
# Processing Record 4 of Set 9 | sokolo
# Processing Record 5 of Set 9 | jalalabad
# Processing Record 6 of Set 9 | sorong
# Processing Record 7 of Set 9 | natal
# Processing Record 8 of Set 9 | capaci
# Processing Record 9 of Set 9 | nioro
# Processing Record 10 of Set 9 | joshimath
# Processing Record 11 of Set 9 | ormara
# Processing Record 12 of Set 9 | rorvik
# Processing Record 13 of Set 9 | nanortalik
# Processing Record 14 of Set 9 | pangody
# Processing Record 15 of Set 9 | lima
# Processing Record 16 of Set 9 | killorglin
# Processing Record 17 of Set 9 | ferkessedougou
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | gamba
# Processing Record 20 of Set 9 | terrace
# Processing Record 21 of Set 9 | shenkursk
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | nouadhibou
# Processing Record 24 of Set 9 | mozirje
# Processing Record 25 of Set 9 | marienburg
# Processing Record 26 of Set 9 | tura
# Processing Record 27 of Set 9 | vitim
# Processing Record 28 of Set 9 | bandundu
# Processing Record 29 of Set 9 | cap malheureux
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | agnibilekrou
# Processing Record 32 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 9 | hay river
# Processing Record 34 of Set 9 | requena
# Processing Record 35 of Set 9 | yumen
# Processing Record 36 of Set 9 | carlisle
# Processing Record 37 of Set 9 | xique-xique
# Processing Record 38 of Set 9 | matagami
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | marrakesh
# Processing Record 41 of Set 9 | nantucket
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | devils lake
# Processing Record 44 of Set 9 | baza
# Processing Record 45 of Set 9 | nabire
# Processing Record 46 of Set 9 | mehamn
# Processing Record 47 of Set 9 | mount isa
# Processing Record 48 of Set 9 | omsukchan
# Processing Record 49 of Set 9 | skibbereen
# Processing Record 0 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 10 | dunedin
# Processing Record 2 of Set 10 | nattarasankottai
# Processing Record 3 of Set 10 | fiumicino
# Processing Record 4 of Set 10 | kampene
# Processing Record 5 of Set 10 | nouakchott
# Processing Record 6 of Set 10 | three hills
# Processing Record 7 of Set 10 | fort frances
# Processing Record 8 of Set 10 | krivosheino
# Processing Record 9 of Set 10 | tarauaca
# Processing Record 10 of Set 10 | olafsvik
# Processing Record 11 of Set 10 | san policarpo
# Processing Record 12 of Set 10 | pacifica
# Processing Record 13 of Set 10 | progreso
# Processing Record 14 of Set 10 | cape canaveral
# Processing Record 15 of Set 10 | manggar
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | vastseliina
# Processing Record 18 of Set 10 | obo
# Processing Record 19 of Set 10 | avera
# Processing Record 20 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 10 | providencia
# Processing Record 22 of Set 10 | tooele
# Processing Record 23 of Set 10 | vanimo
# Processing Record 24 of Set 10 | saint-francois
# Processing Record 25 of Set 10 | vardo
# Processing Record 26 of Set 10 | bubaque
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | luanda
# Processing Record 29 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 10 | azul
# Processing Record 31 of Set 10 | mokrous
# Processing Record 32 of Set 10 | deputatskiy
# Processing Record 33 of Set 10 | skeldon
# Processing Record 34 of Set 10 | kota kinabalu
# Processing Record 35 of Set 10 | kermen
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | bonthe
# Processing Record 38 of Set 10 | iqaluit
# Processing Record 39 of Set 10 | smithers
# Processing Record 40 of Set 10 | bac lieu
# Processing Record 41 of Set 10 | chicama
# Processing Record 42 of Set 10 | celestun
# Processing Record 43 of Set 10 | horki
# Processing Record 44 of Set 10 | vila franca do campo
# Processing Record 45 of Set 10 | portadown
# Processing Record 46 of Set 10 | otane
# Processing Record 47 of Set 10 | arzgir
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | tuatapere
# Processing Record 0 of Set 11 | ayna
# Processing Record 1 of Set 11 | namibe
# Processing Record 2 of Set 11 | mountain home
# Processing Record 3 of Set 11 | vestmanna
# Processing Record 4 of Set 11 | aripuana
# Processing Record 5 of Set 11 | biscarrosse
# Processing Record 6 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 7 of Set 11 | quesnel
# Processing Record 8 of Set 11 | kidodi
# Processing Record 9 of Set 11 | porto nacional
# Processing Record 10 of Set 11 | phu ly
# Processing Record 11 of Set 11 | nova olinda do norte
# Processing Record 12 of Set 11 | burica
# City not found. Skipping...
# Processing Record 13 of Set 11 | kachug
# Processing Record 14 of Set 11 | kerema
# Processing Record 15 of Set 11 | karpathos
# Processing Record 16 of Set 11 | shubarkuduk
# Processing Record 17 of Set 11 | davidson
# Processing Record 18 of Set 11 | harindanga
# Processing Record 19 of Set 11 | tingo maria
# Processing Record 20 of Set 11 | glendive
# Processing Record 21 of Set 11 | vila
# Processing Record 22 of Set 11 | changji
# Processing Record 23 of Set 11 | takoradi
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | tual
# Processing Record 26 of Set 11 | panuco
# Processing Record 27 of Set 11 | kieta
# Processing Record 28 of Set 11 | roros
# Processing Record 29 of Set 11 | oranjemund
# Processing Record 30 of Set 11 | castlemaine
# Processing Record 31 of Set 11 | oksfjord
# Processing Record 32 of Set 11 | camana
# Processing Record 33 of Set 11 | shipunovo
# Processing Record 34 of Set 11 | alugan
# Processing Record 35 of Set 11 | lyuban
# Processing Record 36 of Set 11 | dongying
# Processing Record 37 of Set 11 | buenos aires
# Processing Record 38 of Set 11 | richards bay
# Processing Record 39 of Set 11 | saint-denis
# Processing Record 40 of Set 11 | inirida
# Processing Record 41 of Set 11 | zabol
# Processing Record 42 of Set 11 | bobo dioulasso
# Processing Record 43 of Set 11 | passo de camaragibe
# Processing Record 44 of Set 11 | spirit river
# Processing Record 45 of Set 11 | jadu
# Processing Record 46 of Set 11 | talgar
# Processing Record 47 of Set 11 | cairns
# Processing Record 48 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 49 of Set 11 | kalemie
# Processing Record 0 of Set 12 | ukiah
# Processing Record 1 of Set 12 | svecha
# Processing Record 2 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 3 of Set 12 | morondava
# Processing Record 4 of Set 12 | jumla
# Processing Record 5 of Set 12 | namikupa
# Processing Record 6 of Set 12 | glace bay
# Processing Record 7 of Set 12 | sur
# Processing Record 8 of Set 12 | dingle
# Processing Record 9 of Set 12 | vanavara
# Processing Record 10 of Set 12 | botou
# Processing Record 11 of Set 12 | alice
# Processing Record 12 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 13 of Set 12 | santiago del estero
# Processing Record 14 of Set 12 | bambanglipuro
# Processing Record 15 of Set 12 | port hedland
# Processing Record 16 of Set 12 | port hardy
# Processing Record 17 of Set 12 | kedrovyy
# Processing Record 18 of Set 12 | port augusta
# Processing Record 19 of Set 12 | raga
# Processing Record 20 of Set 12 | mao
# Processing Record 21 of Set 12 | newton
# Processing Record 22 of Set 12 | martinsburg
# Processing Record 23 of Set 12 | kondoa
# Processing Record 24 of Set 12 | killybegs
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | quelimane
# Processing Record 27 of Set 12 | springbok
# Processing Record 28 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 12 | ginda
# Processing Record 30 of Set 12 | broome
# Processing Record 31 of Set 12 | venice
# Processing Record 32 of Set 12 | belmonte
# Processing Record 33 of Set 12 | vancouver
# Processing Record 34 of Set 12 | inhambane
# Processing Record 35 of Set 12 | sri aman
# Processing Record 36 of Set 12 | port blair
# Processing Record 37 of Set 12 | manado
# Processing Record 38 of Set 12 | taganak
# Processing Record 39 of Set 12 | jegunovce
# Processing Record 40 of Set 12 | njombe
# Processing Record 41 of Set 12 | angoche
# Processing Record 42 of Set 12 | marzuq
# Processing Record 43 of Set 12 | opuwo
# Processing Record 44 of Set 12 | kimbe
# Processing Record 45 of Set 12 | prince albert
# Processing Record 46 of Set 12 | olinda
# Processing Record 47 of Set 12 | dukat
# Processing Record 48 of Set 12 | kahului
# Processing Record 49 of Set 12 | gondanglegi
# Processing Record 0 of Set 13 | fairbanks
# Processing Record 1 of Set 13 | alta floresta
# Processing Record 2 of Set 13 | westport
# Processing Record 3 of Set 13 | les cayes
# Processing Record 4 of Set 13 | hastings
# Processing Record 5 of Set 13 | northam
# Processing Record 6 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 13 | tiarei
# Processing Record 8 of Set 13 | wanning
# Processing Record 9 of Set 13 | taltal
# Processing Record 10 of Set 13 | jackson
# Processing Record 11 of Set 13 | wasilla
# Processing Record 12 of Set 13 | kurumkan
# Processing Record 13 of Set 13 | klaksvik
# Processing Record 14 of Set 13 | coos bay
# Processing Record 15 of Set 13 | hampton
# Processing Record 16 of Set 13 | nova vicosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  geraldton -28.7667  114.6000    287.38        58         100        7.20
# 1     kodiak  57.7900 -152.4072    281.88        71         100        3.60
# 2      bluff -46.6000  168.3333    286.08        86         100        9.22
# 3     atuona  -9.8000 -139.0333    300.57        78           7        7.90
# 4  caravelas -17.7125  -39.2481    295.28        91           7        3.37
#
#   Country        Date
# 0      AU  1685062392
# 1      US  1685062392
# 2      NZ  1685062392
# 3      PF  1685062392
# 4      BR  1685062393

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../WeatherPy/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../WeatherPy/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        geraldton -28.7667  114.6000    287.38        58         100
# 1           kodiak  57.7900 -152.4072    281.88        71         100
# 2            bluff -46.6000  168.3333    286.08        86         100
# 3           atuona  -9.8000 -139.0333    300.57        78           7
# 4        caravelas -17.7125  -39.2481    295.28        91           7
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      AU  1685062392
# 1              3.60      US  1685062392
# 2              9.22      NZ  1685062392
# 3              7.90      PF  1685062392
# 4              3.37      BR  1685062393

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude v. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mps)")
plt.grid(True)

# Save the figure
plt.savefig("../WeatherPy/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot(data,x_column,y_column):
    x = data[x_column]
    y = data[y_column]

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             kodiak  57.7900 -152.4072    281.88        71         100
# 6              seoul  37.5683  126.9778    294.91        46           0
# 8        yellowknife  62.4560 -114.3525    287.44        51          40
# 9             jasper  37.2001  -94.3502    299.18        48         100
# 12              lasa  46.6166   10.7002    285.64        84           4
#
#          Wind Speed Country        Date
# City_ID
# 1              3.60      US  1685062392
# 6              2.57      KR  1685062206
# 8              4.12      CA  1685062338
# 9              1.54      US  1685062394
# 12             0.56      IT  1685062395

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           geraldton -28.7667  114.6000    287.38        58         100
# 2               bluff -46.6000  168.3333    286.08        86         100
# 3              atuona  -9.8000 -139.0333    300.57        78           7
# 4           caravelas -17.7125  -39.2481    295.28        91           7
# 5        constitucion -35.3333  -72.4167    284.35        81           4
#
#          Wind Speed Country        Date
# City_ID
# 0              7.20      AU  1685062392
# 2              9.22      NZ  1685062392
# 3              7.90      PF  1685062392
# 4              3.37      BR  1685062393
# 5              2.80      CL  1685062256

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Max Temp')

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Max Temp')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
